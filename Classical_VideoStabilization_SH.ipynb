# %%
#Classical Way

# #note: args Setting catalog
# path  
# name
# RADIUS_SMOOTH
# scale_value
# goodFeaturesToTrack(...)

# cv2.calcOpticalFlowPyrLK(...)
# cv2.goodFeaturesToTrack(...)

# "direction":
# # out = cv2.VideoWriter(path+file_name+'_out_'+date_time+'.avi', fourcc, fps, (w * 3, h))
# out = cv2.VideoWriter(path+file_name+'_out_'+date_time+'.avi', fourcc, fps, (w, h * 3))

# # frame_out = cv2.hconcat([frame_circle,frame, frame_stabilized_original])
#   frame_out = cv2.vconcat([frame_circle,frame, frame_stabilized_original])




import numpy as np
import cv2



def movementAverage(curve, radius): 
  window_size = 2 * radius + 1
  # Set a filter filter
  filter = np.ones(window_size)/window_size 
  # Add padding
  curve_pad = np.lib.pad(curve, (radius, radius), 'edge') 
  # Convolute 
  curve_smooth = np.convolve(curve_pad, filter, mode='same') 
  # Delete padding 
  curve_smooth = curve_smooth[radius:-radius]
  # Return smoothed curve
  return curve_smooth 

def getSmooth(trajectory,radius_smooth_value): 
  trajectory_smooth = np.copy(trajectory) 
  # Filter x, y and angle curves
  for i in range(3):
    trajectory_smooth[:,i] = movementAverage(trajectory[:,i], radius = radius_smooth_value)
  return trajectory_smooth

def scaleImage(frame,scale_value):
  fs = frame.shape
  # Scale the frame image to scale_value with fixed center
  #Transformation matrix
  Trans_Matrix = cv2.getRotationMatrix2D((fs[1]/2, fs[0]/2), 0, scale_value)
  # cv2.warpAffine(img,M,(rows,cols))
  frame = cv2.warpAffine(frame, Trans_Matrix, (fs[1], fs[0]))
  return frame

# Read input video
path = './drive/MyDrive/ColabFiles/IVPProject/'
# file_name = 'video.mp4'
# file_name = 'IMG_4015.mp4'
# file_name = 'IMG_4019.MOV'
# file_name = 'IMG_4020.MOV' 
# file_name = 'Underwater.mp4'
# file_name = 'IMG_4067.MOV'

#test three videos
# file_name = 'Forward.mp4'
# file_name = 'Still.MOV'
file_name = 'Random.MOV'
file_name = 'Deep_learning_video.mp4'
cap = cv2.VideoCapture(path+file_name) 

 
# Get the frame count
num_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT)) 
 
# Get the width and height
w = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH)) 
h = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

# Get frames per second
fps = cap.get(cv2.CAP_PROP_FPS)


# Read frame from the first image
_, prev = cap.read() 
 
# Convert frame to grayscale
previous_gray = cv2.cvtColor(prev, cv2.COLOR_BGR2GRAY) 

# Set transformation matrix
transforms = np.zeros((num_frames-1, 3), np.float32) 

# Save key points as a list
all_keypoints = list()

# Attention: except first frame, so "-2"
for i in range(num_frames-2):
  # Detect feature points in previous frame
  previous_points = cv2.goodFeaturesToTrack(previous_gray,
                                     maxCorners=200,
                                     qualityLevel=0.02,
                                     minDistance=20,
                                     blockSize=3)
  #Save valid key points
  single_image_keypoints = list()
  if previous_points is not None and len(previous_points)>0:
        for x,y in np.float32(previous_points).reshape(-1,2):
            single_image_keypoints.append((x,y))
  all_keypoints.append((single_image_keypoints))

  
  # Read next frame
  success, curr = cap.read() 
  
  if not success: 
    break 

  # Convert to grayscale
  current_gray = cv2.cvtColor(curr, cv2.COLOR_BGR2GRAY) 

  # Calculate optical flow
  current_points, status, err = cv2.calcOpticalFlowPyrLK(previous_gray, current_gray, previous_points, None) 

  
  # Select valid points
  idx = np.where(status==1)[0]
  previous_points = previous_points[idx]
  current_points = current_points[idx]

  # Find transformation matrix
  m,inlier = cv2.estimateAffine2D(previous_points, current_points)

  # Extract the translation
  dx = m[0,2]
  dy = m[1,2]

  # Extract the rotation angle
  da = np.arctan2(m[1,0], m[0,0])
   
  # Save transformation
  transforms[i] = [dx,dy,da]
   
  # Forward to next frame
  previous_gray = current_gray

  print("Frame Process: " + str(i) +  "/" + str(num_frames) + " - Points : " + str(len(previous_points)))

# Compute trajectory
trajectory = np.cumsum(transforms, axis=0) 
 
# Large -> stable,
# Small -> sensitive to quick movement such as a sudden panning
# RADIUS_SMOOTH=50 
# RADIUS_SMOOTH=100
RADIUS_SMOOTH=1000

# Calculate smoothed trajectory
trajectory_smooth = getSmooth(trajectory,RADIUS_SMOOTH) 

# Calculate difference between trajectory_smooth and trajectory
difference = trajectory_smooth - trajectory
 
# Calculate newer transformation array
transformation_smooth = transforms + difference
# Out:
# Frame Process: 0/486 - Points : 200
# Frame Process: 1/486 - Points : 200
# Frame Process: 2/486 - Points : 200
# Frame Process: 3/486 - Points : 200
# Frame Process: 4/486 - Points : 200
# Frame Process: 5/486 - Points : 200
# Frame Process: 6/486 - Points : 199
# Frame Process: 7/486 - Points : 199
# Frame Process: 8/486 - Points : 200
# Frame Process: 9/486 - Points : 200
# Frame Process: 10/486 - Points : 200
# Frame Process: 11/486 - Points : 200
# Frame Process: 12/486 - Points : 200
# Frame Process: 13/486 - Points : 200
# Frame Process: 14/486 - Points : 200
# Frame Process: 15/486 - Points : 200
# Frame Process: 16/486 - Points : 200
# Frame Process: 17/486 - Points : 200
# Frame Process: 18/486 - Points : 200
# Frame Process: 19/486 - Points : 200
# Frame Process: 20/486 - Points : 200
# Frame Process: 21/486 - Points : 200
# Frame Process: 22/486 - Points : 200
# Frame Process: 23/486 - Points : 200
# Frame Process: 24/486 - Points : 200
# Frame Process: 25/486 - Points : 200
# Frame Process: 26/486 - Points : 200
# Frame Process: 27/486 - Points : 200
# Frame Process: 28/486 - Points : 200
# Frame Process: 29/486 - Points : 200
# Frame Process: 30/486 - Points : 200
# Frame Process: 31/486 - Points : 199
# Frame Process: 32/486 - Points : 200
# Frame Process: 33/486 - Points : 200
# Frame Process: 34/486 - Points : 200
# Frame Process: 35/486 - Points : 200
# Frame Process: 36/486 - Points : 200
# Frame Process: 37/486 - Points : 200
# Frame Process: 38/486 - Points : 200
# Frame Process: 39/486 - Points : 200
# Frame Process: 40/486 - Points : 200
# Frame Process: 41/486 - Points : 200
# Frame Process: 42/486 - Points : 199
# Frame Process: 43/486 - Points : 198
# Frame Process: 44/486 - Points : 200
# Frame Process: 45/486 - Points : 199
# Frame Process: 46/486 - Points : 198
# Frame Process: 47/486 - Points : 199
# Frame Process: 48/486 - Points : 198
# Frame Process: 49/486 - Points : 200
# Frame Process: 50/486 - Points : 199
# Frame Process: 51/486 - Points : 199
# Frame Process: 52/486 - Points : 198
# Frame Process: 53/486 - Points : 197
# Frame Process: 54/486 - Points : 199
# Frame Process: 55/486 - Points : 200
# Frame Process: 56/486 - Points : 196
# Frame Process: 57/486 - Points : 197
# Frame Process: 58/486 - Points : 189
# Frame Process: 59/486 - Points : 195
# Frame Process: 60/486 - Points : 190
# Frame Process: 61/486 - Points : 200
# Frame Process: 62/486 - Points : 196
# Frame Process: 63/486 - Points : 198
# Frame Process: 64/486 - Points : 197
# Frame Process: 65/486 - Points : 200
# Frame Process: 66/486 - Points : 200
# Frame Process: 67/486 - Points : 198
# Frame Process: 68/486 - Points : 196
# Frame Process: 69/486 - Points : 196
# Frame Process: 70/486 - Points : 199
# Frame Process: 71/486 - Points : 199
# Frame Process: 72/486 - Points : 198
# Frame Process: 73/486 - Points : 197
# Frame Process: 74/486 - Points : 196
# Frame Process: 75/486 - Points : 199
# Frame Process: 76/486 - Points : 200
# Frame Process: 77/486 - Points : 199
# Frame Process: 78/486 - Points : 198
# Frame Process: 79/486 - Points : 199
# Frame Process: 80/486 - Points : 198
# Frame Process: 81/486 - Points : 198
# Frame Process: 82/486 - Points : 196
# Frame Process: 83/486 - Points : 196
# Frame Process: 84/486 - Points : 197
# Frame Process: 85/486 - Points : 194
# Frame Process: 86/486 - Points : 195
# Frame Process: 87/486 - Points : 197
# Frame Process: 88/486 - Points : 200
# Frame Process: 89/486 - Points : 194
# Frame Process: 90/486 - Points : 184
# Frame Process: 91/486 - Points : 186
# Frame Process: 92/486 - Points : 196
# Frame Process: 93/486 - Points : 193
# Frame Process: 94/486 - Points : 199
# Frame Process: 95/486 - Points : 199
# Frame Process: 96/486 - Points : 198
# Frame Process: 97/486 - Points : 200
# Frame Process: 98/486 - Points : 196
# Frame Process: 99/486 - Points : 195
# Frame Process: 100/486 - Points : 192
# Frame Process: 101/486 - Points : 199
# Frame Process: 102/486 - Points : 199
# Frame Process: 103/486 - Points : 198
# Frame Process: 104/486 - Points : 194
# Frame Process: 105/486 - Points : 181
# Frame Process: 106/486 - Points : 171
# Frame Process: 107/486 - Points : 184
# Frame Process: 108/486 - Points : 193
# Frame Process: 109/486 - Points : 199
# Frame Process: 110/486 - Points : 196
# Frame Process: 111/486 - Points : 194
# Frame Process: 112/486 - Points : 194
# Frame Process: 113/486 - Points : 197
# Frame Process: 114/486 - Points : 195
# Frame Process: 115/486 - Points : 197
# Frame Process: 116/486 - Points : 195
# Frame Process: 117/486 - Points : 178
# Frame Process: 118/486 - Points : 181
# Frame Process: 119/486 - Points : 195
# Frame Process: 120/486 - Points : 198
# Frame Process: 121/486 - Points : 191
# Frame Process: 122/486 - Points : 192
# Frame Process: 123/486 - Points : 195
# Frame Process: 124/486 - Points : 198
# Frame Process: 125/486 - Points : 194
# Frame Process: 126/486 - Points : 194
# Frame Process: 127/486 - Points : 193
# Frame Process: 128/486 - Points : 189
# Frame Process: 129/486 - Points : 188
# Frame Process: 130/486 - Points : 195
# Frame Process: 131/486 - Points : 193
# Frame Process: 132/486 - Points : 195
# Frame Process: 133/486 - Points : 195
# Frame Process: 134/486 - Points : 172
# Frame Process: 135/486 - Points : 199
# Frame Process: 136/486 - Points : 196
# Frame Process: 137/486 - Points : 198
# Frame Process: 138/486 - Points : 196
# Frame Process: 139/486 - Points : 186
# Frame Process: 140/486 - Points : 189
# Frame Process: 141/486 - Points : 190
# Frame Process: 142/486 - Points : 198
# Frame Process: 143/486 - Points : 197
# Frame Process: 144/486 - Points : 196
# Frame Process: 145/486 - Points : 198
# Frame Process: 146/486 - Points : 194
# Frame Process: 147/486 - Points : 171
# Frame Process: 148/486 - Points : 165
# Frame Process: 149/486 - Points : 176
# Frame Process: 150/486 - Points : 178
# Frame Process: 151/486 - Points : 177
# Frame Process: 152/486 - Points : 195
# Frame Process: 153/486 - Points : 192
# Frame Process: 154/486 - Points : 194
# Frame Process: 155/486 - Points : 197
# Frame Process: 156/486 - Points : 183
# Frame Process: 157/486 - Points : 190
# Frame Process: 158/486 - Points : 196
# Frame Process: 159/486 - Points : 199
# Frame Process: 160/486 - Points : 196
# Frame Process: 161/486 - Points : 195
# Frame Process: 162/486 - Points : 193
# Frame Process: 163/486 - Points : 199
# Frame Process: 164/486 - Points : 198
# Frame Process: 165/486 - Points : 196
# Frame Process: 166/486 - Points : 192
# Frame Process: 167/486 - Points : 183
# Frame Process: 168/486 - Points : 200
# Frame Process: 169/486 - Points : 198
# Frame Process: 170/486 - Points : 182
# Frame Process: 171/486 - Points : 183
# Frame Process: 172/486 - Points : 190
# Frame Process: 173/486 - Points : 197
# Frame Process: 174/486 - Points : 194
# Frame Process: 175/486 - Points : 195
# Frame Process: 176/486 - Points : 198
# Frame Process: 177/486 - Points : 185
# Frame Process: 178/486 - Points : 193
# Frame Process: 179/486 - Points : 197
# Frame Process: 180/486 - Points : 191
# Frame Process: 181/486 - Points : 180
# Frame Process: 182/486 - Points : 181
# Frame Process: 183/486 - Points : 194
# Frame Process: 184/486 - Points : 199
# Frame Process: 185/486 - Points : 197
# Frame Process: 186/486 - Points : 197
# Frame Process: 187/486 - Points : 198
# Frame Process: 188/486 - Points : 196
# Frame Process: 189/486 - Points : 199
# Frame Process: 190/486 - Points : 199
# Frame Process: 191/486 - Points : 195
# Frame Process: 192/486 - Points : 197
# Frame Process: 193/486 - Points : 191
# Frame Process: 194/486 - Points : 197
# Frame Process: 195/486 - Points : 197
# Frame Process: 196/486 - Points : 197
# Frame Process: 197/486 - Points : 200
# Frame Process: 198/486 - Points : 192
# Frame Process: 199/486 - Points : 192
# Frame Process: 200/486 - Points : 198
# Frame Process: 201/486 - Points : 200
# Frame Process: 202/486 - Points : 199
# Frame Process: 203/486 - Points : 199
# Frame Process: 204/486 - Points : 186
# Frame Process: 205/486 - Points : 197
# Frame Process: 206/486 - Points : 198
# Frame Process: 207/486 - Points : 198
# Frame Process: 208/486 - Points : 196
# Frame Process: 209/486 - Points : 196
# Frame Process: 210/486 - Points : 200
# Frame Process: 211/486 - Points : 199
# Frame Process: 212/486 - Points : 191
# Frame Process: 213/486 - Points : 193
# Frame Process: 214/486 - Points : 186
# Frame Process: 215/486 - Points : 192
# Frame Process: 216/486 - Points : 191
# Frame Process: 217/486 - Points : 195
# Frame Process: 218/486 - Points : 196
# Frame Process: 219/486 - Points : 191
# Frame Process: 220/486 - Points : 188
# Frame Process: 221/486 - Points : 195
# Frame Process: 222/486 - Points : 193
# Frame Process: 223/486 - Points : 197
# Frame Process: 224/486 - Points : 197
# Frame Process: 225/486 - Points : 191
# Frame Process: 226/486 - Points : 192
# Frame Process: 227/486 - Points : 195
# Frame Process: 228/486 - Points : 197
# Frame Process: 229/486 - Points : 195
# Frame Process: 230/486 - Points : 195
# Frame Process: 231/486 - Points : 198
# Frame Process: 232/486 - Points : 196
# Frame Process: 233/486 - Points : 187
# Frame Process: 234/486 - Points : 184
# Frame Process: 235/486 - Points : 196
# Frame Process: 236/486 - Points : 191
# Frame Process: 237/486 - Points : 194
# Frame Process: 238/486 - Points : 195
# Frame Process: 239/486 - Points : 198
# Frame Process: 240/486 - Points : 190
# Frame Process: 241/486 - Points : 192
# Frame Process: 242/486 - Points : 198
# Frame Process: 243/486 - Points : 196
# Frame Process: 244/486 - Points : 192
# Frame Process: 245/486 - Points : 198
# Frame Process: 246/486 - Points : 191
# Frame Process: 247/486 - Points : 185
# Frame Process: 248/486 - Points : 190
# Frame Process: 249/486 - Points : 195
# Frame Process: 250/486 - Points : 196
# Frame Process: 251/486 - Points : 199
# Frame Process: 252/486 - Points : 195
# Frame Process: 253/486 - Points : 200
# Frame Process: 254/486 - Points : 195
# Frame Process: 255/486 - Points : 189
# Frame Process: 256/486 - Points : 193
# Frame Process: 257/486 - Points : 181
# Frame Process: 258/486 - Points : 195
# Frame Process: 259/486 - Points : 188
# Frame Process: 260/486 - Points : 184
# Frame Process: 261/486 - Points : 186
# Frame Process: 262/486 - Points : 193
# Frame Process: 263/486 - Points : 195
# Frame Process: 264/486 - Points : 196
# Frame Process: 265/486 - Points : 199
# Frame Process: 266/486 - Points : 196
# Frame Process: 267/486 - Points : 192
# Frame Process: 268/486 - Points : 188
# Frame Process: 269/486 - Points : 190
# Frame Process: 270/486 - Points : 197
# Frame Process: 271/486 - Points : 198
# Frame Process: 272/486 - Points : 199
# Frame Process: 273/486 - Points : 197
# Frame Process: 274/486 - Points : 199
# Frame Process: 275/486 - Points : 198
# Frame Process: 276/486 - Points : 193
# Frame Process: 277/486 - Points : 193
# Frame Process: 278/486 - Points : 184
# Frame Process: 279/486 - Points : 196
# Frame Process: 280/486 - Points : 197
# Frame Process: 281/486 - Points : 192
# Frame Process: 282/486 - Points : 192
# Frame Process: 283/486 - Points : 196
# Frame Process: 284/486 - Points : 199
# Frame Process: 285/486 - Points : 195
# Frame Process: 286/486 - Points : 195
# Frame Process: 287/486 - Points : 195
# Frame Process: 288/486 - Points : 196
# Frame Process: 289/486 - Points : 196
# Frame Process: 290/486 - Points : 197
# Frame Process: 291/486 - Points : 199
# Frame Process: 292/486 - Points : 198
# Frame Process: 293/486 - Points : 196
# Frame Process: 294/486 - Points : 196
# Frame Process: 295/486 - Points : 197
# Frame Process: 296/486 - Points : 194
# Frame Process: 297/486 - Points : 187
# Frame Process: 298/486 - Points : 190
# Frame Process: 299/486 - Points : 192
# Frame Process: 300/486 - Points : 183
# Frame Process: 301/486 - Points : 199
# Frame Process: 302/486 - Points : 194
# Frame Process: 303/486 - Points : 198
# Frame Process: 304/486 - Points : 197
# Frame Process: 305/486 - Points : 197
# Frame Process: 306/486 - Points : 197
# Frame Process: 307/486 - Points : 197
# Frame Process: 308/486 - Points : 197
# Frame Process: 309/486 - Points : 195
# Frame Process: 310/486 - Points : 196
# Frame Process: 311/486 - Points : 190
# Frame Process: 312/486 - Points : 197
# Frame Process: 313/486 - Points : 197
# Frame Process: 314/486 - Points : 193
# Frame Process: 315/486 - Points : 199
# Frame Process: 316/486 - Points : 199
# Frame Process: 317/486 - Points : 198
# Frame Process: 318/486 - Points : 192
# Frame Process: 319/486 - Points : 193
# Frame Process: 320/486 - Points : 189
# Frame Process: 321/486 - Points : 184
# Frame Process: 322/486 - Points : 190
# Frame Process: 323/486 - Points : 196
# Frame Process: 324/486 - Points : 196
# Frame Process: 325/486 - Points : 195
# Frame Process: 326/486 - Points : 190
# Frame Process: 327/486 - Points : 194
# Frame Process: 328/486 - Points : 199
# Frame Process: 329/486 - Points : 193
# Frame Process: 330/486 - Points : 198
# Frame Process: 331/486 - Points : 199
# Frame Process: 332/486 - Points : 197
# Frame Process: 333/486 - Points : 196
# Frame Process: 334/486 - Points : 195
# Frame Process: 335/486 - Points : 198
# Frame Process: 336/486 - Points : 196
# Frame Process: 337/486 - Points : 196
# Frame Process: 338/486 - Points : 197
# Frame Process: 339/486 - Points : 193
# Frame Process: 340/486 - Points : 197
# Frame Process: 341/486 - Points : 195
# Frame Process: 342/486 - Points : 197
# Frame Process: 343/486 - Points : 195
# Frame Process: 344/486 - Points : 193
# Frame Process: 345/486 - Points : 198
# Frame Process: 346/486 - Points : 195
# Frame Process: 347/486 - Points : 196
# Frame Process: 348/486 - Points : 194
# Frame Process: 349/486 - Points : 198
# Frame Process: 350/486 - Points : 195
# Frame Process: 351/486 - Points : 198
# Frame Process: 352/486 - Points : 196
# Frame Process: 353/486 - Points : 193
# Frame Process: 354/486 - Points : 196
# Frame Process: 355/486 - Points : 197
# Frame Process: 356/486 - Points : 196
# Frame Process: 357/486 - Points : 197
# Frame Process: 358/486 - Points : 194
# Frame Process: 359/486 - Points : 196
# Frame Process: 360/486 - Points : 194
# Frame Process: 361/486 - Points : 197
# Frame Process: 362/486 - Points : 188
# Frame Process: 363/486 - Points : 191
# Frame Process: 364/486 - Points : 194
# Frame Process: 365/486 - Points : 188
# Frame Process: 366/486 - Points : 195
# Frame Process: 367/486 - Points : 197
# Frame Process: 368/486 - Points : 193
# Frame Process: 369/486 - Points : 193
# Frame Process: 370/486 - Points : 197
# Frame Process: 371/486 - Points : 197
# Frame Process: 372/486 - Points : 198
# Frame Process: 373/486 - Points : 196
# Frame Process: 374/486 - Points : 195
# Frame Process: 375/486 - Points : 200
# Frame Process: 376/486 - Points : 200
# Frame Process: 377/486 - Points : 197
# Frame Process: 378/486 - Points : 193
# Frame Process: 379/486 - Points : 199
# Frame Process: 380/486 - Points : 197
# Frame Process: 381/486 - Points : 199
# Frame Process: 382/486 - Points : 196
# Frame Process: 383/486 - Points : 194
# Frame Process: 384/486 - Points : 189
# Frame Process: 385/486 - Points : 194
# Frame Process: 386/486 - Points : 188
# Frame Process: 387/486 - Points : 195
# Frame Process: 388/486 - Points : 197
# Frame Process: 389/486 - Points : 196
# Frame Process: 390/486 - Points : 197
# Frame Process: 391/486 - Points : 195
# Frame Process: 392/486 - Points : 191
# Frame Process: 393/486 - Points : 196
# Frame Process: 394/486 - Points : 195
# Frame Process: 395/486 - Points : 196
# Frame Process: 396/486 - Points : 196
# Frame Process: 397/486 - Points : 198
# Frame Process: 398/486 - Points : 198
# Frame Process: 399/486 - Points : 197
# Frame Process: 400/486 - Points : 194
# Frame Process: 401/486 - Points : 196
# Frame Process: 402/486 - Points : 198
# Frame Process: 403/486 - Points : 197
# Frame Process: 404/486 - Points : 196
# Frame Process: 405/486 - Points : 199
# Frame Process: 406/486 - Points : 190
# Frame Process: 407/486 - Points : 187
# Frame Process: 408/486 - Points : 184
# Frame Process: 409/486 - Points : 195
# Frame Process: 410/486 - Points : 196
# Frame Process: 411/486 - Points : 192
# Frame Process: 412/486 - Points : 197
# Frame Process: 413/486 - Points : 192
# Frame Process: 414/486 - Points : 184
# Frame Process: 415/486 - Points : 192
# Frame Process: 416/486 - Points : 196
# Frame Process: 417/486 - Points : 195
# Frame Process: 418/486 - Points : 189
# Frame Process: 419/486 - Points : 175
# Frame Process: 420/486 - Points : 182
# Frame Process: 421/486 - Points : 181
# Frame Process: 422/486 - Points : 183
# Frame Process: 423/486 - Points : 188
# Frame Process: 424/486 - Points : 183
# Frame Process: 425/486 - Points : 170
# Frame Process: 426/486 - Points : 200
# Frame Process: 427/486 - Points : 193
# Frame Process: 428/486 - Points : 194
# Frame Process: 429/486 - Points : 191
# Frame Process: 430/486 - Points : 189
# Frame Process: 431/486 - Points : 196
# Frame Process: 432/486 - Points : 195
# Frame Process: 433/486 - Points : 190
# Frame Process: 434/486 - Points : 198
# Frame Process: 435/486 - Points : 198
# Frame Process: 436/486 - Points : 196
# Frame Process: 437/486 - Points : 185
# Frame Process: 438/486 - Points : 174
# Frame Process: 439/486 - Points : 192
# Frame Process: 440/486 - Points : 198
# Frame Process: 441/486 - Points : 197
# Frame Process: 442/486 - Points : 197
# Frame Process: 443/486 - Points : 193
# Frame Process: 444/486 - Points : 190
# Frame Process: 445/486 - Points : 193
# Frame Process: 446/486 - Points : 199
# Frame Process: 447/486 - Points : 198
# Frame Process: 448/486 - Points : 199
# Frame Process: 449/486 - Points : 196
# Frame Process: 450/486 - Points : 197
# Frame Process: 451/486 - Points : 196
# Frame Process: 452/486 - Points : 197
# Frame Process: 453/486 - Points : 200
# Frame Process: 454/486 - Points : 193
# Frame Process: 455/486 - Points : 198
# Frame Process: 456/486 - Points : 192
# Frame Process: 457/486 - Points : 196
# Frame Process: 458/486 - Points : 190
# Frame Process: 459/486 - Points : 187
# Frame Process: 460/486 - Points : 198
# Frame Process: 461/486 - Points : 199
# Frame Process: 462/486 - Points : 199
# Frame Process: 463/486 - Points : 199
# Frame Process: 464/486 - Points : 199
# Frame Process: 465/486 - Points : 200
# Frame Process: 466/486 - Points : 199
# Frame Process: 467/486 - Points : 200
# Frame Process: 468/486 - Points : 200
# Frame Process: 469/486 - Points : 200
# Frame Process: 470/486 - Points : 199
# Frame Process: 471/486 - Points : 199
# Frame Process: 472/486 - Points : 199
# Frame Process: 473/486 - Points : 198
# Frame Process: 474/486 - Points : 200
# Frame Process: 475/486 - Points : 199
# Frame Process: 476/486 - Points : 200
# Frame Process: 477/486 - Points : 199
# Frame Process: 478/486 - Points : 200
# Frame Process: 479/486 - Points : 200
# Frame Process: 480/486 - Points : 198
# Frame Process: 481/486 - Points : 199
# Frame Process: 482/486 - Points : 199
# Frame Process: 483/486 - Points : 200

# %%
# all_keypoints[0]
# w
# Out:
# 1920

# %%
# Set the four character code for output
# In Python, "*" could help divide the string and send the args one by one
fourcc = cv2.VideoWriter_fourcc(*'MJPG')

import time

# Set time format to 2016-03-20 11:22:33
date_time = time.strftime("%Y-%m-%d %H:%M:%S", time.localtime()) 
# out = cv2.VideoWriter(path+file_name+'_out_'+date_time+'.avi', fourcc, fps, (w * 3, h))
out = cv2.VideoWriter(path+file_name+'_out_'+date_time+'.avi', fourcc, fps, (w, h * 3))


# Get back to first frame in the stream
cap.set(cv2.CAP_PROP_POS_FRAMES, 0) 

# Write num_frames-1 transformed frames
for i in range(num_frames-2):
  # Read next frame
  success, frame = cap.read() 
  if not success:
    break

  


  # Extract transformations from the new transformation matrix
  dx = transformation_smooth[i,0]
  dy = transformation_smooth[i,1]
  da = transformation_smooth[i,2]

  # Reconstruct transformation matrix
  m = np.zeros((2,3), np.float32)
  m[0,0] = np.cos(da)
  m[0,1] = -np.sin(da)
  m[1,0] = np.sin(da)
  m[1,1] = np.cos(da)
  m[0,2] = dx
  m[1,2] = dy

  # Apply affine wrapping
  frame_stabilized = cv2.warpAffine(frame, m, (w,h))

  # Scale border artifacts
  SCALE_VALUE = 1.2
  frame_stabilized = scaleImage(frame_stabilized,SCALE_VALUE) 


  # Write the frame to the file
  
  import copy

  # Display 3 colors and 2 color
  # frame[:,:,0]=0
  # frame[:,:,1]=0
  frame_stabilized_original = copy.deepcopy(frame_stabilized)
  # frame_stabilized[:,:,1]=0
  frame_stabilized[:,:,2]=0
  
  frame_circle = frame[:]

  # Show key points
  local_keypoints = all_keypoints[i]
  if local_keypoints is not None and len(local_keypoints)>0:
    for x,y in local_keypoints:
      cv2.circle(frame_circle, (int(x),int(y)), 5, (255,255,0))

  # Make it transparent and set a overlay view.
  ALPHA = 0.62
  frame = ((1-ALPHA) * frame.astype(np.float) + ALPHA * frame_stabilized.astype(np.float)).astype(np.uint8)

  # frame_out = cv2.hconcat([frame_circle,frame, frame_stabilized_original])
  frame_out = cv2.vconcat([frame_circle,frame, frame_stabilized_original])

  
  # res = cv2.addWeighted(img_cat, 0.8, img_dog_1, 0.6, 0)  # 权重 权重 偏置值


  # # Resize large image
  # if(frame_out.shape[1] > 2000): 
  #   frame_out = cv2.resize(frame_out, (frame_out.shape[1]//2, frame_out.shape[0]//2));
  
  # from google.colab.patches import cv2_imshow
  # cv2.imshow("Before and After", frame_out)
  cv2.waitKey(10)
  out.write(frame_out)

# Release
# cap.release()
out.release()

# Close
# cv2.destroyAllWindows()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
